# %%
# imports

import pandas as pd

df = pd.read_excel("WCNeutras_respostas_full.xlsx")
df
# Out:
#           Submission Date                     Instituição de ensino superior  \
# 0     2022/07/15 14:43:05     Universidade de Lisboa - Faculdade de Ciências
# 1     2022/07/15 09:44:34     Universidade de Lisboa - Faculdade de Ciências
# 2     2022/07/14 20:22:04                                              Outra
# 3     2022/07/14 20:19:10     Universidade de Lisboa - Faculdade de Ciências
# 4     2022/07/14 18:05:42     Universidade de Lisboa - Faculdade de Ciências
# ...                   ...                                                ...
# 1333  2022/05/21 13:27:50     Universidade de Lisboa - Faculdade de Ciências
# 1334  2022/05/20 17:02:08  Universidade Nova de Lisboa - School of Busine...
# 1335  2022/05/18 17:30:42  Universidade Nova de Lisboa - School of Busine...
# 1336  2022/05/18 16:37:56  Universidade Nova de Lisboa - School of Busine...
# 1337  2022/05/18 15:09:00  Universidade Nova de Lisboa - School of Busine...
#
#      Se outra, qual? Dentro da minha instituição sou       Idade  \
# 0                NaN                         Docente  mais de 50
# 1                NaN                   Investigadore       27-29
# 2               ISEL                           Alune       30-39
# 3                NaN                           Alune       20-21
# 4                NaN                        Ex-alune       30-39
# ...              ...                             ...         ...
# 1333             NaN                           Alune       22-23
# 1334             NaN                           Alune       22-23
# 1335             NaN                           Alune       22-23
# 1336             NaN                           Alune       24-26
# 1337             NaN                           Alune       20-21
#
#         Orientação sexual Caso queiras especificar:  \
# 0           Heteressexual                       NaN
# 1           Heteressexual                       NaN
# 2                Assexual                       NaN
# 3           Heteressexual                       NaN
# 4           Heteressexual                       NaN
# ...                   ...                       ...
# 1333  Bissexual/Pansexual                       NaN
# 1334        Heteressexual                       NaN
# 1335  Bissexual/Pansexual                       NaN
# 1336        Heteressexual                       NaN
# 1337        Heteressexual                       NaN
#
#                     Identidade de género Caso queiras especificar:.1  \
# 0                       Mulher cisgénero                         NaN
# 1                       Mulher cisgénero                         NaN
# 2                        Homem cisgénero                         NaN
# 3                       Mulher cisgénero                         NaN
# 4                       Mulher cisgénero                         NaN
# ...                                  ...                         ...
# 1333                     Homem cisgénero                         NaN
# 1334                    Mulher cisgénero                         NaN
# 1335                  Pessoa não-binária                    Demigirl
# 1336                    Mulher cisgénero                         NaN
# 1337  Não me identifico com estas opções                         NaN
#
#      Sou intersexo:  ...  \
# 0               Não  ...
# 1               Não  ...
# 2               Não  ...
# 3               Não  ...
# 4               Não  ...
# ...             ...  ...
# 1333            Não  ...
# 1334            Não  ...
# 1335            Não  ...
# 1336            Não  ...
# 1337            Não  ...
#
#      Já usaste uma casa de banho neutra num espaço público?  \
# 0                                                   NÃO
# 1                                                   NÃO
# 2                                                   SIM
# 3                                                   NÃO
# 4                                                   NÃO
# ...                                                 ...
# 1333                                                SIM
# 1334                                                SIM
# 1335                                                NÃO
# 1336                                                NÃO
# 1337                                                NÃO
#
#      Quão confortável te sentes ao usar...  \
# 0                                      NaN
# 1                                      NaN
# 2                                        4
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 1333                                     5
# 1334                                     5
# 1335                                   NaN
# 1336                                   NaN
# 1337                                   NaN
#
#      Quão confortável achas que te sentirias ao usar...  \
# 0                                                     2
# 1                                                    3
# 2                                                   NaN
# 3                                                     2
# 4                                                     4
# ...                                                 ...
# 1333                                                NaN
# 1334                                                NaN
# 1335                                                  5
# 1336                                                  1
# 1337                                                  2
#
#      Queres justificar a tua resposta à pergunta anterior?  \
# 0     não me sentiria confortável com homens dentro ...
# 1     Não me iria sentir confortável com a presença ...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1333                                                NaN
# 1334                                                NaN
# 1335                                                NaN
# 1336                                                NaN
# 1337                                                NaN
#
#      A tua instituição tem casas de banho neutras?  \
# 0                                              Não
# 1                              Não tenho a certeza
# 2                                              Sim
# 3                                              Não
# 4                              Não tenho a certeza
# ...                                            ...
# 1333                                           Não
# 1334                                           Não
# 1335                                           Não
# 1336                                           Não
# 1337                                           Não
#
#      Como funcionam e quantas há?  \
# 0                             NaN
# 1                             NaN
# 2                               1
# 3                             NaN
# 4                             NaN
# ...                           ...
# 1333                          NaN
# 1334                          NaN
# 1335                          NaN
# 1336                          NaN
# 1337                          NaN
#
#      Já sofreste discriminação ao utilizar uma casa de banho pública?  \
# 0                                                   Não
# 1                                                   Não
# 2                                                   Não
# 3                                                   Não
# 4                                                   Não
# ...                                                 ...
# 1333                                                Sim
# 1334                                                Não
# 1335                                                Não
# 1336                                                Não
# 1337                                                Não
#
#      Esse episódio de discriminação foi numa instituição de ensino superior?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1333                              Prefiro não responder
# 1334                                                NaN
# 1335                                                NaN
# 1336                                                NaN
# 1337                                                NaN
#
#      Como seria para ti uma casa de banho neutra segura?  \
# 0                                                   NaN
# 1     Não sei como possa ser estabelecido um control...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1333                                                NaN
# 1334                                                NaN
# 1335  Stalls, everything that implies sexual organs ...
# 1336  I would not necessarily feel drawn to it, but ...
# 1337                                                NaN
#
#      Há mais alguma coisa que gostarias de nos dizer?
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1333                                              NaN
# 1334                                              NaN
# 1335                    Thank you for this initiative
# 1336                                              NaN
# 1337                                              NaN
#
# [1338 rows x 28 columns]

# %%
# lista com índices de respostas potencialmente a gozar (índice do xlsx)
troll_list = [49, 54, 57, 58, 61, 66, 68, 69, 70, 71, 72, 74, 75, 76, 77, 97, 193, 229, 268,
              271, 357, 474, 505, 589, 645, 668, 959, 960, 1022, 1082, 1092, 1264, 1279, 1314]

# conversão em índices da df
troll_list = [x-2 for x in troll_list]
len(troll_list)
# Out:
# 34

# %% [markdown]
# rever trolls?

# %%
# lista com índices (python) de respostas duplicadas
dups_list = [482, 504, 685, 748, 793, 852, 944, 965, 969, 1050, 1278]
len(dups_list)
# Out:
# 11

# %%
to_elim_list = troll_list + dups_list
len(to_elim_list)
# Out:
# 45

# %%
# retirar linhas com índices em to_elim_list
df.drop(to_elim_list)
# Out:
#           Submission Date                     Instituição de ensino superior  \
# 0     2022/07/15 14:43:05     Universidade de Lisboa - Faculdade de Ciências
# 1     2022/07/15 09:44:34     Universidade de Lisboa - Faculdade de Ciências
# 2     2022/07/14 20:22:04                                              Outra
# 3     2022/07/14 20:19:10     Universidade de Lisboa - Faculdade de Ciências
# 4     2022/07/14 18:05:42     Universidade de Lisboa - Faculdade de Ciências
# ...                   ...                                                ...
# 1333  2022/05/21 13:27:50     Universidade de Lisboa - Faculdade de Ciências
# 1334  2022/05/20 17:02:08  Universidade Nova de Lisboa - School of Busine...
# 1335  2022/05/18 17:30:42  Universidade Nova de Lisboa - School of Busine...
# 1336  2022/05/18 16:37:56  Universidade Nova de Lisboa - School of Busine...
# 1337  2022/05/18 15:09:00  Universidade Nova de Lisboa - School of Busine...
#
#      Se outra, qual? Dentro da minha instituição sou       Idade  \
# 0                NaN                         Docente  mais de 50
# 1                NaN                   Investigadore       27-29
# 2               ISEL                           Alune       30-39
# 3                NaN                           Alune       20-21
# 4                NaN                        Ex-alune       30-39
# ...              ...                             ...         ...
# 1333             NaN                           Alune       22-23
# 1334             NaN                           Alune       22-23
# 1335             NaN                           Alune       22-23
# 1336             NaN                           Alune       24-26
# 1337             NaN                           Alune       20-21
#
#         Orientação sexual Caso queiras especificar:  \
# 0           Heteressexual                       NaN
# 1           Heteressexual                       NaN
# 2                Assexual                       NaN
# 3           Heteressexual                       NaN
# 4           Heteressexual                       NaN
# ...                   ...                       ...
# 1333  Bissexual/Pansexual                       NaN
# 1334        Heteressexual                       NaN
# 1335  Bissexual/Pansexual                       NaN
# 1336        Heteressexual                       NaN
# 1337        Heteressexual                       NaN
#
#                     Identidade de género Caso queiras especificar:.1  \
# 0                       Mulher cisgénero                         NaN
# 1                       Mulher cisgénero                         NaN
# 2                        Homem cisgénero                         NaN
# 3                       Mulher cisgénero                         NaN
# 4                       Mulher cisgénero                         NaN
# ...                                  ...                         ...
# 1333                     Homem cisgénero                         NaN
# 1334                    Mulher cisgénero                         NaN
# 1335                  Pessoa não-binária                    Demigirl
# 1336                    Mulher cisgénero                         NaN
# 1337  Não me identifico com estas opções                         NaN
#
#      Sou intersexo:  ...  \
# 0               Não  ...
# 1               Não  ...
# 2               Não  ...
# 3               Não  ...
# 4               Não  ...
# ...             ...  ...
# 1333            Não  ...
# 1334            Não  ...
# 1335            Não  ...
# 1336            Não  ...
# 1337            Não  ...
#
#      Já usaste uma casa de banho neutra num espaço público?  \
# 0                                                   NÃO
# 1                                                   NÃO
# 2                                                   SIM
# 3                                                   NÃO
# 4                                                   NÃO
# ...                                                 ...
# 1333                                                SIM
# 1334                                                SIM
# 1335                                                NÃO
# 1336                                                NÃO
# 1337                                                NÃO
#
#      Quão confortável te sentes ao usar...  \
# 0                                      NaN
# 1                                      NaN
# 2                                        4
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 1333                                     5
# 1334                                     5
# 1335                                   NaN
# 1336                                   NaN
# 1337                                   NaN
#
#      Quão confortável achas que te sentirias ao usar...  \
# 0                                                     2
# 1                                                    3
# 2                                                   NaN
# 3                                                     2
# 4                                                     4
# ...                                                 ...
# 1333                                                NaN
# 1334                                                NaN
# 1335                                                  5
# 1336                                                  1
# 1337                                                  2
#
#      Queres justificar a tua resposta à pergunta anterior?  \
# 0     não me sentiria confortável com homens dentro ...
# 1     Não me iria sentir confortável com a presença ...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1333                                                NaN
# 1334                                                NaN
# 1335                                                NaN
# 1336                                                NaN
# 1337                                                NaN
#
#      A tua instituição tem casas de banho neutras?  \
# 0                                              Não
# 1                              Não tenho a certeza
# 2                                              Sim
# 3                                              Não
# 4                              Não tenho a certeza
# ...                                            ...
# 1333                                           Não
# 1334                                           Não
# 1335                                           Não
# 1336                                           Não
# 1337                                           Não
#
#      Como funcionam e quantas há?  \
# 0                             NaN
# 1                             NaN
# 2                               1
# 3                             NaN
# 4                             NaN
# ...                           ...
# 1333                          NaN
# 1334                          NaN
# 1335                          NaN
# 1336                          NaN
# 1337                          NaN
#
#      Já sofreste discriminação ao utilizar uma casa de banho pública?  \
# 0                                                   Não
# 1                                                   Não
# 2                                                   Não
# 3                                                   Não
# 4                                                   Não
# ...                                                 ...
# 1333                                                Sim
# 1334                                                Não
# 1335                                                Não
# 1336                                                Não
# 1337                                                Não
#
#      Esse episódio de discriminação foi numa instituição de ensino superior?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1333                              Prefiro não responder
# 1334                                                NaN
# 1335                                                NaN
# 1336                                                NaN
# 1337                                                NaN
#
#      Como seria para ti uma casa de banho neutra segura?  \
# 0                                                   NaN
# 1     Não sei como possa ser estabelecido um control...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1333                                                NaN
# 1334                                                NaN
# 1335  Stalls, everything that implies sexual organs ...
# 1336  I would not necessarily feel drawn to it, but ...
# 1337                                                NaN
#
#      Há mais alguma coisa que gostarias de nos dizer?
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1333                                              NaN
# 1334                                              NaN
# 1335                    Thank you for this initiative
# 1336                                              NaN
# 1337                                              NaN
#
# [1293 rows x 28 columns]

# %% [markdown]
# TODO
# - substituir valores em 'Instituição de ensino superior' == 'Outra' com valor em 'Se outra, qual?'
# - passar valores a minusculas e sem acentos (é -> e, ç -> c, etc)
# - ver valores distintos nessa col
# - ...
